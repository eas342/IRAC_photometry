# %%
from astropy.io import fits, ascii
from photutils import CircularAperture, CircularAnnulus
import numpy as np
import functions as func
import matplotlib.pyplot as plt
import pdb, glob, mpld3
from mpld3 import plugins
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10, 8)
mpld3.enable_notebook()

# %%
bcd_2506 = np.sort(glob.glob("ngc2506/unzipped_AORs/ch1/bcd/*_bcd.fits"))
bimsk_2506 = np.sort(glob.glob("ngc2506/unzipped_AORs/ch1/bcd/*_bimsk.fits"))
bunc_2506 = np.sort(glob.glob("ngc2506/unzipped_AORs/ch1/bcd/*_bunc.fits"))
cbcd_2506 = np.sort(glob.glob("ngc2506/unzipped_AORs/ch1/bcd/*_cbcd.fits"))
cbunc_2506 = np.sort(glob.glob("ngc2506/unzipped_AORs/ch1/bcd/*_cbunc.fits"))

# %%
hdu = fits.open(bcd_2506[10])
hdu.info()
# Out:
# Filename: ngc2506/unzipped_AORs/ch1/bcd/SPITZER_I1_17133824_0010_0000_3_bcd.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     321   (256, 256)   float32

# %%
hdu[0].header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / FOUR-BYTE SINGLE PRECISION FLOATING POINT
# NAXIS   =                    2 / STANDARD FITS FORMAT
# NAXIS1  =                  256 / STANDARD FITS FORMAT
# NAXIS2  =                  256 / STANDARD FITS FORMAT
# ORIGIN  = 'Spitzer Science Center' / Organization generating this FITS file
# CREATOR = 'S18.25.0'           / SW version used to create this FITS file
# TELESCOP= 'Spitzer '           / SPITZER Space Telescope
# INSTRUME= 'IRAC    '           / SPITZER Space Telescope instrument ID
# CHNLNUM =                    1 / 1 digit instrument channel number
# EXPTYPE = 'sci     '           / Exposure Type
# REQTYPE = 'AOR     '           / Request type (AOR, IER, or  SER)
# AOT_TYPE= 'IracMap '           / Observation template type
# AORLABEL= 'IRAC-jwstcal_ngc2506' / AOR Label
# FOVID   =                   81 / Field of View ID
# FOVNAME = 'IRAC_FOV_bwn_3.6&5.8_and_4.5&8.0_for_mapping' / Field of View Name
#
#           / PROPOSAL INFORMATION
#
# OBSRVR  = 'William Reach'      / Observer Name (Last, First)
# OBSRVRID=                  125 / Observer ID of Principal Investigator
# PROCYCL =                    3 / Proposal Cycle
# PROGID  =                 1158 / Program ID
# PROTITLE= 'SIRTF IRAC Calibration Program' / Program Title
# PROGCAT =                   32 / Program Category
#
#           / TIME AND EXPOSURE INFORMATION
#
# DATE_OBS= '2006-05-03T09:54:25.623' / Date & time (UTC) at DCE start
# UTCS_OBS=        199922065.623 / [sec] DCE start time from noon, Jan 1, 2000 UTC
# MJD_OBS =        53858.4127966 / [days] MJD in UTC at DCE start (,JD-2400000.5)
# HMJD_OBS=        53858.4137653 / [days] Corresponding Helioc. Mod. Julian Date
# BMJD_OBS=        53858.4137677 / [days] Solar System Barycenter Mod. Julian Date
# ET_OBS  =        199922130.809 / [sec] DCE start time (TDB seconds past J2000)
# SCLK_OBS=        831117553.371 / [sec] SCLK time (since 1/1/1980) at DCE start
# SPTZR_X =    -137183227.526522 / [km] Heliocentric J2000 x position
# SPTZR_Y =     -55904463.968445 / [km] Heliocentric J2000 y position
# SPTZR_Z =     -27255069.690507 / [km] Heliocentric J2000 z position
# SPTZR_VX=            12.049626 / [km/s] Heliocentric J2000 x velocity
# SPTZR_VY=           -24.901991 / [km/s] Heliocentric J2000 y velocity
# SPTZR_VZ=           -11.042246 / [km/s] Heliocentric J2000 z velocity
# SPTZR_LT=           502.425329 / [sec] One-way light time to Sun's center
# AORTIME =                  30. / [sec] Frameset selected in IRAC AOT
# SAMPTIME=                  0.2 / [sec] Sample integration time
# FRAMTIME=                  1.2 / [sec] Time spent integrating (whole array)
# COMMENT   Photons in Well = Flux[photons/sec/pixel] * FRAMTIME
# EXPTIME =                   1. / [sec] Effective integration time per pixel
# COMMENT   DN per pixel = Flux[photons/sec/pixel] / GAIN * EXPTIME
# FRAMEDLY=                 10.8 / [sec] Frame Delay Time
# FRDLYDET= 'T       '           / Frame Delay Time Determinable (T or F)
# INTRFDLY=                 10.8 / [sec] Inter Frame Delay Time
# IMDLYDET= 'T       '           / Immediate Delay Time Determinable (T or F)
# AINTBEG =            564190.88 / [Secs since IRAC turn-on] Time of integ. start
# ATIMEEND=            564192.05 / [Secs since IRAC turn-on] Time of integ. end
# AFOWLNUM=                    1 / Fowler number
# AWAITPER=                    4 / [0.2 sec] Wait period
# ANUMREPS=                    1 / Number of repeat integrations
# AREADMOD=                    0 / Full (0) or subarray (1)
# AORHDR  =                    T / Requested AOT is HDR mode
# HDRMODE =                    T / DCE taken in High Dynamic Range mode
# HDRFRAME= '   short'           / Position in HDR observation
# HDRCYCLE=                    6 / Cycle of HDR observation
# ABARREL =                    0 / Barrel shift
# APEDSIG =                    0 / 0=Normal, 1=Pedestal, 2=Signal
#
#           / TARGET AND POINTING INFORMATION
#
# OBJECT  = 'NGC2506 '           / Target Name
# OBJTYPE = 'TargetFixedSingle'  / Object Type
# CRPIX1  =                 128. / Reference pixel along axis 1
# CRPIX2  =                 128. / Reference pixel along axis 2
# CRVAL1  =     120.077128169612 / [deg] RA at CRPIX1,CRPIX2 (using Ptg. Recon.)
# CRVAL2  =    -10.7268598715403 / [deg] DEC at CRPIX1,CRPIX2 (using Ptg. Recon.)
# PTGCPD  = 'Yes     '           / Pointing Keywords Copied from Long Frame
# CRDER1  = 3.86035963910228E-05 / [deg] Uncertainty in CRVAL1
# CRDER2  = 3.84928819086906E-05 / [deg] Uncertainty in CRVAL2
# RA_HMS  = '08h00m18.5s'        / [hh:mm:ss.s] CRVAL1 as sexagesimal
# DEC_DMS = '-10d43m37s'         / [dd:mm:ss] CRVAL2 as sexagesimal
# RADESYS = 'ICRS    '           / International Celestial Reference System
# EQUINOX =                2000. / Equinox for ICRS celestial coord. system
# CD1_1   = 5.50369147753529E-05 / Corrected CD matrix element with Ptg. Recon.
# CD1_2   = 0.000335261748156131 / Corrected CD matrix element with Ptg. Recon.
# CD2_1   = 0.000335330791527176 / Corrected CD matrix element with Ptg. Recon.
# CD2_2   = -5.53558558928324E-05 / Corrected CD matrix element with Ptg. Recon.
# CTYPE1  = 'RA---TAN-SIP'       / RA---TAN with distortion in pixel space
# CTYPE2  = 'DEC--TAN-SIP'       / DEC--TAN with distortion in pixel space
# PXSCAL1 =    -1.22334117768332 / [arcsec/pix] Scale for axis 1 at CRPIX1,CRPIX2
# PXSCAL2 =     1.22328355209902 / [arcsec/pix] Scale for axis 2 at CRPIX1,CRPIX2
# PA      =     99.3755961630889 / [deg] Position angle of axis 2 (E of N)
# UNCRTPA = 0.000307127273980738 / [deg] Uncertainty in position angle
# CSDRADEC= 1.12216182627634E-06 / [deg] Costandard deviation in RA and Dec
# SIGRA   =   0.0250110171740623 / [arcsec] RMS dispersion of RA over DCE
# SIGDEC  =   0.0163740648597209 / [arcsec] RMS dispersion of DEC over DCE
# SIGPA   =   0.0272389427098121 / [arcsec] RMS dispersion of PA over DCE
# RA_RQST =     120.077157145956 / [deg] Requested RA at CRPIX1, CRPIX2
# DEC_RQST=     -10.726877141467 / [deg] Requested Dec at CRPIX1, CRPIX2
# PM_RA   =               -0.003 / [arcsec/yr] Proper Motion in RA (J2000)
# PM_DEC  =                   0. / [arcsec/yr] Proper Motion in Dec (J200)
# RMS_JIT =  0.00299364514847702 / [arcsec] RMS jitter during DCE
# RMS_JITY=  0.00238916558655946 / [arcsec] RMS jitter during DCE along Y
# RMS_JITZ=  0.00180382900381383 / [arcsec] RMS jitter during DCE along Z
# SIG_JTYZ= -0.00179883144012995 / [arcsec] Costadard deviation of jitter in YZ
# PTGDIFF =   0.0853992184140754 / [arcsec] Offset btwn actual and rqsted pntng
# PTGDIFFX=  -0.0396526465403756 / [pixels] rqsted - actual pntng along axis 1
# PTGDIFFY=  -0.0755180336408252 / [pixels] rqsted - actual pntng along axis 2
# RA_REF  =     120.004161111111 / [deg] Commanded RA (J2000) of ref. position
# DEC_REF =               -10.77 / [deg] Commanded Dec (J2000) of ref. position
# USEDBPHF=                    T / T if Boresight Pointing History File was used
# BPHFNAME= 'SBPHF.0831081600.012.pntg' / Boresight Pointing History Filename
# FOVVERSN= 'BodyFrames_FTU_14a.xls' / FOV/BodyFrames file version used
# RECONFOV= 'IRAC_Center_of_3.6umArray' / Reconstructed Field of View
# ORIG_RA =     120.077201843262 / [deg] Original RA from raw BPHF
# ORIG_DEC=    -10.7269096374512 / [deg] Original Dec from raw BPHF
# ORIGCD11=       5.50366021E-05 / [deg/pix] Original CD1_1 element
# ORIGCD12=      0.0003352618078 / [deg/pix] Original CD1_2 element
# ORIGCD21=      0.0003353308421 / [deg/pix] Original CD2_1 element
# ORIGCD22=      -5.53555437E-05 / [deg/pix] Original CD2_2 element
#
#
#
#           / DISTORTION KEYWORDS
#
# A_ORDER =                    3 / polynomial order, axis 1, detector to sky
# A_0_2   =           2.9656E-06 / distortion coefficient
# A_0_3   =           3.7746E-09 / distortion coefficient
# A_1_1   =           2.1886E-05 / distortion coefficient
# A_1_2   =          -1.6847E-07 / distortion coefficient
# A_2_0   =          -2.3863E-05 / distortion coefficient
# A_2_1   =           -8.561E-09 / distortion coefficient
# A_3_0   =          -1.4172E-07 / distortion coefficient
# A_DMAX  =                1.394 / [pixel] maximum correction
# B_ORDER =                    3 / polynomial order, axis 2, detector to sky
# B_0_2   =             2.31E-05 / distortion coefficient
# B_0_3   =          -1.6168E-07 / distortion coefficient
# B_1_1   =          -2.4386E-05 / distortion coefficient
# B_1_2   =          -5.7813E-09 / distortion coefficient
# B_2_0   =           2.1197E-06 / distortion coefficient
# B_2_1   =          -1.6583E-07 / distortion coefficient
# B_3_0   =          -2.0249E-08 / distortion coefficient
# B_DMAX  =                1.501 / [pixel] maximum correction
# AP_ORDER=                    3 / polynomial order, axis 1, sky to detector
# AP_0_1  =          -6.4275E-07 / distortion coefficient
# AP_0_2  =          -2.9425E-06 / distortion coefficient
# AP_0_3  =           -3.582E-09 / distortion coefficient
# AP_1_0  =          -1.4897E-05 / distortion coefficient
# AP_1_1  =           -2.225E-05 / distortion coefficient
# AP_1_2  =           1.7195E-07 / distortion coefficient
# AP_2_0  =           2.4146E-05 / distortion coefficient
# AP_2_1  =            6.709E-09 / distortion coefficient
# AP_3_0  =           1.4492E-07 / distortion coefficient
# BP_ORDER=                    3 / polynomial order, axis 2, sky to detector
# BP_0_1  =          -1.6588E-05 / distortion coefficient
# BP_0_2  =          -2.3424E-05 / distortion coefficient
# BP_0_3  =            1.651E-07 / distortion coefficient
# BP_1_0  =          -2.6783E-06 / distortion coefficient
# BP_1_1  =           2.4753E-05 / distortion coefficient
# BP_1_2  =           3.8917E-09 / distortion coefficient
# BP_2_0  =           -2.151E-06 / distortion coefficient
# BP_2_1  =              1.7E-07 / distortion coefficient
# BP_3_0  =           2.0482E-08 / distortion coefficient
#
#           / PHOTOMETRY
#
# BUNIT   = 'MJy/sr  '           / Units of image data
# FLUXCONV=               0.1069 / Flux Conv. factor (MJy/sr per DN/sec)
# GAIN    =                  3.3 / e/DN conversion
# RONOISE =                 22.6 / [Electrons] Readout Noise from Array
# ZODY_EST=           0.06027732 / [MJy/sr] Zodiacal Background Estimate
# ISM_EST =          0.008818666 / [MJy/sr] Interstellar Medium Estimate
# CIB_EST =                   0. / [MJy/sr] Cosmic Infrared Background Estimate
# SKYDRKZB=             0.048112 / [MJy/sr] Zodiacal Background Est of Subtracted
# SKYDKMED=             2.386659 / [MJy/sr] Median of Subtracted Skydark
# SKDKRKEY=             17142528 / Skydark AOR Reqkey
# SKDKTIME=                  30. / [sec] Skydark AOR Duration Time
# SKDKFDLY=                11.84 / [sec] Average Frame Delay Time of Skydark
# SKDKIDLY=                11.84 / [sec] Average Immediate Delay Time of Skydark
#
#           / GENERAL MAPPING KEYWORDS
#
# CYCLENUM=                    6 / Current cycle number
# COLUMN  =                    1 / Current column number
# ROW     =                    1 / Current row number
# MAPNUM  =                    1 / Current map cycle number
# DITHPOS =                    6 / Current dither position
#
#           / IRAC MAPPING KEYWORDS
#
# READMODE= 'FULL    '           / Readout mode (full or sub)
# COLSTEP =                 260. / [arcsec] Column step size
# ROWSTEP =                 260. / [arcsec] Row step size
# COLOFF  =                   0. / [arcsec] Column map center offset
# ROWOFF  =                   0. / [arcsec] Row map center offset
# MAPCOORD= 'Array   '           / Array or celestial coordinates
# DITHSCAL= 'medium  '           / Dither scale (small, medium, large)
#
#           / INSTRUMENT TELEMETRY DATA
#
# ASHTCON =                    2 / Shutter condition (1:closed, 2: open)
# AWEASIDE=                    0 / WEA side in use (0:B, 1:A)
# ACTXSTAT=                    0 / Cmded transcal status
# ATXSTAT =                    0 / transcal status
# ACFLSTAT=                    0 / Cmded floodcal status
# AFLSTAT =                    0 / floodcal status
# AVRSTUCC=                 -3.5 / [Volts] Cmded VRSTUC Bias
# AVRSTBEG=           -3.5114367 / [Volts] VRSTUC Bias at start integration
# AVDETC  =                -2.75 / [Volts] Cmded VDET Bias
# AVDETBEG=           -2.7578687 / [Volts] VDET Bias at start of integration
# AVGG1C  =                -3.65 / [Volts] Cmded VGG1 Bias
# AVGG1BEG=           -3.2078801 / [Volts] VGG1 Bias at start of integration
# AVDDUCC =                 -3.5 / [Volts] Cmded VDDUC Bias
# AVDDUBEG=           -3.5003509 / [Volts] VDDUC Bias at start integration
# AVGGCLC =                   1. / [Volts] Cmnded VGGCL clock rail voltage
# AVGGCBEG=                   1. / [Volts] VGGCL clock rail voltage
# AHTRIBEG=            205.00668 / [uAmps] Heater current at start of integ
# AHTRVBEG=            2.3924802 / [Volts] Heater Voltage at start integ.
# AFPAT2B =            15.022535 / [Deg_K] FPA Temp sensor #2 at start integ.
# AFPAT2BT=              564174. / [Sec] FPA Temp sensor #2 time tag
# AFPAT2E =            15.022535 / [Deg_K] FPA temp sensor #2, end integ.
# AFPAT2ET=              564174. / [Sec] FPA temp sensor #2 time tag
# ACTENDT =            20.803505 / [Deg_C] C&T board thermistor
# AFPECTE =            18.744149 / [Deg_C] FPE control board thermistor
# AFPEATE =            22.253345 / [Deg_C] FPE analog board thermistor
# ASHTEMPE=            21.992257 / [Deg_C] Shutter board thermistor
# ATCTEMPE=            23.150528 / [Deg_C] Temp. controller board thermistor
# ACETEMPE=            20.712062 / [Deg_C] Calib. electronics board thermistor
# APDTEMPE=            20.498696 / [Deg_C] PDU board thermistor
# ACATMP1E=            1.3148744 / [Deg_K] CA Temp, Foot 2
# ACATMP2E=              1.29808 / [Deg_K] CA Temp, Foot 1
# ACATMP3E=            1.3301334 / [Deg_K] CA Temp, Shutter
# ACATMP4E=            1.3268948 / [Deg_K] CA Temp, Top OMH
# ACATMP5E=            1.3249464 / [Deg_K] CA Temp, Bottom OMH
# ACATMP6E=             1.323451 / [Deg_K] CA Temp, Top TxCal Sphere
# ACATMP7E=            1.3222183 / [Deg_K] CA Temp, Bottom TxCal Sphere
# ACATMP8E=            1.3152152 / [Deg_K] CA Temp, Foot 3
#
#           / DATA FLOW KEYWORDS
#
# ORIGIN0 = 'JPL_FOS '           / Site where RAW FITS file was written
# CREATOR0= 'J5.3    '           / SW system that created RAW FITS
# DATE    = '2010-12-13T02:48:33' / [YYYY-MM-DDThh:mm:ss UTC] file creation date
# AORKEY  =             17133824 / AOR or EIR key. Astrnmy Obs Req/Instr Eng Req
# DS_IDENT= 'ads/sa.spitzer#0017133824' / Data Set Identification for ADS/journals
# EXPID   =                   10 / Exposure ID (0-9999)
# DCENUM  =                    0 / DCE number (0-9999)
# TLMGRPS =                    1 / expected number of groups
# FILE_VER=                    1 / Version of the raw file made by SIS
# RAWFILE = 'IRAC.1.0017133824.0010.0000.01.mipl.fits' / Raw data file name
# CPT_VER = '3.1.11  '           / Channel Param Table FOS versioN
# CTD_VER = '3.0.94S '           / Cmded telemetry data version
# EXPDFLAG=                    T / (T/F) expedited DCE
# MISS_LCT=                    0 / Total Missed Line Cnt in this FITS
# MANCPKT =                    F / T if this FITS is Missing Ancillary Data
# MISSDATA=                    F / T if this FITS is Missing Image Data
# BADTRIG =                    F / Bad data (zero pixel) was located in raw frame
# CHECKSUM=                    0 / MIPL computed checksum
# PAONUM  =                 1807 / PAO Number
# CAMPAIGN= 'IRAC008000'         / Campaign
# DCEID   =             54051977 / Data-Collection-Event ID
# DCEINSID=             12036459 / DCE Instance ID
# DPID    =            342147670 / Data Product Instance ID
# PIPENUM =                  107 / Pipeline Script Number
# SOS_VER =                    1 / Data-Product Version
# PLVID   =                    4 / Pipeline Version ID
# CALID   =                    6 / CalTrans Version ID
# SDRKEPID=              8403582 / Sky Dark ensemble product ID
# PMSKFBID=                 1959 / Pixel mask ID
# LDRKFBID=                  916 / Fall-back lab dark ID
# LINCFBID=                  357 / Fall-back Linearity correction ID
# FLATFBID=                 1589 / Fall-back flat ID
# FLXCFBID=                 1898 / Flux conversion ID
# MBLTFBID=                 1186 / Muxbleed Lookup Table ID
# MBCFFBID=                 1175 / Muxbleed Coefficients ID
# LBDRKFLE= 'HDR_30s_1.2sf1d1r1_ch1_v1.2.0_dark.txt' / Labdark File Used
# LBDRKTD = 'F       '           / Labdark Time Dependent (T or F)
# DDCORR1 =            0.1189093 / Darkdrift Correction for Readout Channel 1
# DDCORR2 =             0.036154 / Darkdrift Correction for Readout Channel 2
# DDCORR3 =           -0.1603811 / Darkdrift Correction for Readout Channel 3
# DDCORR4 =          0.005317823 / Darkdrift Correction for Readout Channel 4
# DDBKGND =            0.5249718 / Darkdrift 'Background' Term
#
#
#
#           / PROCESSING HISTORY
#
# HISTORY job.c ver: 1.50
# HISTORY TRANHEAD                  v.         13.1, ran Sun Dec 12 18:46:45 2010
# HISTORY CALTRANS                 v.        4.0, ran Sun Dec 12 18:47:03 2010
# HISTORY INSBPOSDOM                v.          1.1, ran Sun Dec 12 18:47:03 2010
# HISTORY cvti2r4           v.  1.31 A61025, generated 12/12/10 at 18:47:08
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:47:15
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:47:19
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:47:23
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:47:28
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:47:33
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:47:37
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:47:42
# HISTORY FFC                       v.          1.0, ran Sun Dec 12 18:47:44 2010
# HISTORY MUXBLEEDCORR              v.        1.600, ran Sun Dec 12 18:47:49 2010
# HISTORY FOWLINEARIZE              v.     4.900000, ran Sun Dec 12 18:47:50 2010
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:47:54
# HISTORY BGMODEL                   v.          1.0, ran Sun Dec 12 18:47:54 2010
# HISTORY SLREMOVE                  v.          1.0, ran Sun Dec 12 18:47:55 2010
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:47:59
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:48:03
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:48:08
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:48:12
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:48:17
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/12/10 at 18:48:21
# HISTORY DARKSUBNG                 v. 1.000, ran Sun Dec 12 18:48:22 2010
# HISTORY DARKDRIFT                 v.          4.1, ran Sun Dec 12 18:48:23 2010
# HISTORY FLATAP                    v. 1.500   Sun Dec 12 18:48:25 2010
# HISTORY DNTOFLUX                  v.          4.2, ran Sun Dec 12 18:48:33 2010
# HISTORY CALTRANS                 v.        4.0, ran Sun Dec 12 18:52:47 2010
# HISTORY CALTRANS                 v.        4.0, ran Sat Dec 18 08:39:00 2010
# HISTORY PTNTRAN                   v.          1.4, ran Sat Dec 18 08:39:01 2010
# HISTORY FPGen                     v.         1.26, ran Sat Dec 18 08:39:03 2010
# HISTORY PTGADJUST                 v.          1.0, ran Sat Dec 18 09:09:55 2010
# HISTORY Data rescaled using correct flux conversion : 25 Jul 2012 01:01:00 PDT
# HISTORY FLUXCONV rescaled from 0.1069 to 0.1069 : 25 Jul 2012 01:01:00 PDT
# HISTORY FLUXCONV updated in header : 25 Jul 2012 01:01:00 PDT
# HISTORY CREATOR keyword updated : 25 Jul 2012 01:01:00 PDT

# %%
fig1, ax1 = plt.subplots()
ax1.imshow(hdu[0].data)
plugins.connect(fig1, plugins.MousePosition(fontsize=14))

# %%
bimsk_hdu = fits.open(bimsk_2506[10])
bimsk_hdu.info()
# Out:
# Filename: ngc2506/unzipped_AORs/ch1/bcd/SPITZER_I1_17133824_0010_0000_3_bimsk.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      87   (256, 256)   int16

# %%
bimsk_hdu[0].header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                   16 / FOUR-BYTE SINGLE PRECISION FLOATING POINT
# NAXIS   =                    2 / STANDARD FITS FORMAT
# NAXIS1  =                  256 / STANDARD FITS FORMAT
# NAXIS2  =                  256 / STANDARD FITS FORMAT
# ORIGIN  = 'Spitzer Science Center' / Organization generating this FITS file
# CREATOR = 'S18.25.0'           / SW version used to create this FITS file
# TELESCOP= 'Spitzer '           / SPITZER Space Telescope
# INSTRUME= 'IRAC    '           / SPITZER Space Telescope instrument ID
# CHNLNUM =                    1 / 1 digit instrument channel number
#
#
#           / PROPOSAL INFORMATION
#
# OBSRVR  = 'William Reach'      / Observer Name (Last, First)
# OBSRVRID=                  125 / Observer ID of Principal Investigator
# PROCYCL =                    3 / Proposal Cycle
# PROGID  =                 1158 / Program ID
# PROTITLE= 'SIRTF IRAC Calibration Program' / Program Title
# PROGCAT =                   32 / Program Category
#
#           / TIME AND EXPOSURE INFORMATION
#
# DATE_OBS= '2006-05-03T09:54:25.623' / Date & time at DCE start
# MJD_OBS =        53858.4127966 / [days] MJD at DCE start (,JD-2400000.5)
# HMJD_OBS=        53858.4137653 / [days] Corresponding Heliocen. Mod. Julian Date
# BMJD_OBS=        53858.4137677 / [days] Solar System Barycenter Mod. Julian Date
# UTCS_OBS=        199922065.623 / [sec] J2000 ephem. time at DCE start
# SCLK_OBS=        831117553.371 / [sec] SCLK time (since 1/1/1980) at DCE start
# ET_OBS  =        199922130.809 / [sec] Ephemeris time (seconds past J2000 epoch)
# AREADMOD=                    0 / Full (0) or subarray (1)
#
#           / mask pixel Bit representation
#
# BIT00   =                    1 / Overall data quality of imask pixel
# BIT01   =                    2 / Reserved for future use
# BIT02   =                    4 / Set if optical ghost present
# BIT03   =                    8 / Set if stray light present
# BIT04   =                   16 / Set if saturation corrected in pipeline
# BIT05   =                   32 / Set if muxbleed/bandwidth effect present
# BIT06   =                   64 / Set if banding present
# BIT07   =                  128 / Set if column pulldown present
# BIT08   =                  256 / Set if crosstalk present
# BIT09   =                  512 / Set if pixel contains radhit
# BIT10   =                 1024 / Set if pixel contains latent image
# BIT11   =                 2048 / Set if flat field was not applied
# BIT12   =                 4096 / Set if pixel is not linear
# BIT13   =                 8192 / Set if pixel is uncorrected saturation
# BIT14   =                16384 / Set if data is bad or missing
# MBCOUNT =                    0 / MuxBleed Trigger Counts
# PDCOUNT =                    0 / PullDown Trigger Counts
# PROCBITS=                32428 / Processed Bits in IMASK
#
#           / DATA FLOW KEYWORDS
#
# DATE    = '2010-12-13T02:48:33' / [YYYY-MM-DDThh:mm:ss UTC] file creation date
# AORKEY  =             17133824 / AOR or EIR key. Astrnmy Obs Req/Instr Eng Req
# DS_IDENT= 'ads/sa.spitzer#0017133824' / Data Set Identification for ADS/journals
# EXPID   =                   10 / Exposure ID (0-9999)
# DCENUM  =                    0 / DCE number (0-9999)
# FILE_VER=                    1 / Version of the raw file made by SIS
# RAWFILE = 'IRAC.1.0017133824.0010.0000.01.mipl.fits' / Raw data file name
# CTD_VER = '3.0.94S '           / Cmded telemetry data version
# EXPDFLAG=                    T / (T/F) expedited DCE
# PAONUM  =                 1807 / PAO Number
# CAMPAIGN= 'IRAC008000'         / Campaign
# DCEID   =             54051977 / Data-Collection-Event ID
# DCEINSID=             12036459 / DCE Instance ID
# PIPENUM =                  107 / Pipeline Script Number
# SOS_VER =                    1 / Data-Product Version
# PLVID   =                    4 / Pipeline Version ID
#
#
#
#           / PROCESSING HISTORY
#
# HISTORY cvti2r4           v.  1.31 A61025, generated 12/12/10 at 18:47:08
# HISTORY MUXBLEEDCORR              v.        1.600, ran Sun Dec 12 18:47:49 2010
# HISTORY FLATAP                    v. 1.500   Sun Dec 12 18:48:25 2010
# HISTORY genimask                  v.   1.3   Sun Dec 12 19:03:44 2010
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/18/10 at  8:39:04
# HISTORY hdrupd8           v.  1.6  A70821,  updated  12/18/10 at  8:39:05
# HISTORY FPGen                     v.         1.26, ran Sat Dec 18 08:39:05 2010
# HISTORY slgst                     v.   1.0   Sun Dec 19 21:45:44 2010
# HISTORY SATCORR Module version 1.7  image created Sun Dec 19 21:53:16 2010
# HISTORY artiflags                 v.   1.2   Sun Dec 19 23:23:54 2010
# HISTORY CREATOR keyword updated : 25 Jul 2012 01:01:14 PDT

# %%
fig2, ax2 = plt.subplots()
ax2.imshow(bimsk_hdu[0].data)
plugins.connect(fig2, plugins.MousePosition(fontsize=14))

# %%
bunc_hdu = fits.open(bunc_2506[10])
bunc_hdu.info()
# Out:
# Filename: ngc2506/unzipped_AORs/ch1/bcd/SPITZER_I1_17133824_0010_0000_3_bunc.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     333   (256, 256)   float32

# %%
fig3, ax3 = plt.subplots()
ax3.imshow(bunc_hdu[0].data)
plugins.connect(fig3, plugins.MousePosition(fontsize=14))

# %%
cbcd_hdu = fits.open(cbcd_2506[10])
cbcd_hdu.info()
# Out:
# Filename: ngc2506/unzipped_AORs/ch1/bcd/SPITZER_I1_17133824_0010_0000_3_cbcd.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     330   (256, 256)   float32

# %%
fig4, ax4 = plt.subplots()
ax4.imshow(cbcd_hdu[0].data)
plugins.connect(fig4, plugins.MousePosition(fontsize=14))

# %%
cbunc_hdu = fits.open(cbunc_2506[10])
cbunc_hdu.info()
# Out:
# Filename: ngc2506/unzipped_AORs/ch1/bcd/SPITZER_I1_17133824_0010_0000_3_cbunc.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     327   (256, 256)   float32

# %%
fig2, ax2 = plt.subplots()
ax2.imshow(bimsk_hdu[0].data)
plugins.connect(fig2, plugins.MousePosition(fontsize=14))

# %% [markdown]
# # bcd (Basic Calibrated Data) Files

# %%
hdu = fits.open(bcd_2506[5]) #5th bcd file
image = hdu[0].data

# %%
reload(func)
# Out:
# <module 'functions' from 'functions.py'>

# %%
# 10th bcd file
flux, ap = func.photometry(image, [127], [127], rad = 2.25)
bkg_ap = func.photometry(image, [127], [127], shape = 'CircAnn', r_in = 4, r_out = 5)[1]
print flux

fig, ax = plt.subplots()
ax.imshow(image, origin = 'lower')
ap.plot(color='r',linewidth=2)
bkg_ap.plot(color='y', linewidth=2)
plugins.connect(fig, plugins.MousePosition(fontsize=14))
# Out:
# 217.480492915
